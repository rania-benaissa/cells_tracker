# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !python "/content/drive/MyDrive/Colab Notebooks/cell/cell.py" train --dataset="/content/drive/MyDrive/Colab Notebooks/Images/" --weights=imagenet
# Out:
# Le flux de sortie a été tronqué et ne contient que les 5000 dernières lignes.
#
# 2022-12-17 16:15:23.237316: W tensorflow/compiler/mlir/tools/kernel_gen/tf_gpu_runtime_wrappers.cc:30] 'cuModuleUnload(it.second)' failed with 'CUDA_ERROR_NOT_INITIALIZED'
#
# 2022-12-17 16:15:23.237328: W tensorflow/compiler/mlir/tools/kernel_gen/tf_gpu_runtime_wrappers.cc:30] 'cuModuleUnload(it.second)' failed with 'CUDA_ERROR_NOT_INITIALIZED'
#
# 2022-12-17 16:15:23.257417: W tensorflow/compiler/mlir/tools/kernel_gen/tf_gpu_runtime_wrappers.cc:30] 'cuModuleUnload(it.second)' failed with 'CUDA_ERROR_NOT_INITIALIZED'
#
# 2022-12-17 16:15:23.257532: W tensorflow/compiler/mlir/tools/kernel_gen/tf_gpu_runtime_wrappers.cc:30] 'cuModuleUnload(it.second)' failed with 'CUDA_ERROR_NOT_INITIALIZED'
#
# 2022-12-17 16:15:23.257550: W tensorflow/compiler/mlir/tools/kernel_gen/tf_gpu_runtime_wrappers.cc:30] 'cuModuleUnload(it.second)' failed with 'CUDA_ERROR_NOT_INITIALIZED'
#
# ...
